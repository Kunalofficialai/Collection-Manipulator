# %%
students = []

print("===== Welcome to Student Data Organizer =====")

while True:
    print("\n1. Add Student")
    print("2. Display All Students")
    print("3. Update Student")
    print("4. Delete Student")
    print("5. Display Subjects")
    print("6. Exit")

    choice = input("Enter your choice: ")

    
    if choice == "1":

        name = input("Enter Name: ")
        age = int(input("Enter Age: "))
        grade = input("Enter Grade: ")

        subjects_input = input("Enter Subjects separated by comma: ")
        subjects = set(subjects_input.split(","))

        student_id = input("Enter Student ID: ")
        dob = input("Enter Date of Birth: ")

        
        student_info = (student_id, dob)

        
        student = {
            "info": student_info,
            "name": name,
            "age": age,
            "grade": grade,
            "subjects": subjects
        }

        
        students.append(student)

        print("Student Added Successfully!")

    
    elif choice == "2":

        if len(students) == 0:
            print("No student records found.")

        else:
            print("\n===== Student Records =====")

            for s in students:
                print(f"""
Student ID : {s['info'][0]}
Name       : {s['name']}
Age        : {s['age']}
Grade      : {s['grade']}
Subjects   : {", ".join(s['subjects'])}
DOB        : {s['info'][1]}
""")

    
    elif choice == "3":

        sid = input("Enter Student ID to update: ")

        found = False

        for s in students:

            if s["info"][0] == sid:

                new_age = int(input("Enter New Age: "))
                new_subjects = input("Enter New Subjects separated by comma: ")

                s["age"] = new_age
                s["subjects"] = set(new_subjects.split(","))

                print("Student Updated Successfully!")
                found = True
                break

        if found == False:
            print("Student Not Found!")

    
    elif choice == "4":

        sid = input("Enter Student ID to delete: ")

        found = False

        for i in range(len(students)):

            if students[i]["info"][0] == sid:

                del students[i]

                print("Student Deleted Successfully!")
                found = True
                break

        if found == False:
            print("Student Not Found!")

    
    elif choice == "5":

        all_subjects = set()

        for s in students:
            all_subjects.update(s["subjects"])

        print("Unique Subjects Offered:")
        print(all_subjects)

    
    elif choice == "6":

        print("Thank You for using Student Data Organizer!")
        break

    else:
        print("Invalid Choice!")
# Out:
# ===== Welcome to Student Data Organizer =====
#
# 1. Add Student
# 2. Display All Students
# 3. Update Student
# 4. Delete Student
# 5. Display Subjects
# 6. Exit
# Enter your choice:  1
# Enter Name:  Kunal Rajput
# Enter Age:  17
# Enter Grade:  B+
# Enter Subjects separated by comma:  Power Bi
# Enter Student ID:  12819
# Enter Date of Birth:  2007-08-23
# Student Added Successfully!
#
# 1. Add Student
# 2. Display All Students
# 3. Update Student
# 4. Delete Student
# 5. Display Subjects
# 6. Exit
# Enter your choice:  2
# ===== Student Records =====
#
# Student ID : 12819
# Name       : Kunal Rajput
# Age        : 17
# Grade      : B+
# Subjects   : Power Bi
# DOB        : 2007-08-23
#
#
# 1. Add Student
# 2. Display All Students
# 3. Update Student
# 4. Delete Student
# 5. Display Subjects
# 6. Exit
# Enter your choice:  3
# Enter Student ID to update:  12333
# Student Not Found!
#
# 1. Add Student
# 2. Display All Students
# 3. Update Student
# 4. Delete Student
# 5. Display Subjects
# 6. Exit
# Enter your choice:  4
# Enter Student ID to delete:  123333
# Student Not Found!
#
# 1. Add Student
# 2. Display All Students
# 3. Update Student
# 4. Delete Student
# 5. Display Subjects
# 6. Exit
# Enter your choice:  5
# Unique Subjects Offered:
# {'Power Bi'}
#
# 1. Add Student
# 2. Display All Students
# 3. Update Student
# 4. Delete Student
# 5. Display Subjects
# 6. Exit
# Enter your choice:  6
# Thank You for using Student Data Organizer!
